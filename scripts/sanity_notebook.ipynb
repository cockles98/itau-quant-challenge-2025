# %% [markdown]
# # Sanity Notebook\nAdd exploratory analysis for score distributions and rank IC.

# %%
# TODO: load data, compute score distributions\n

# %%
# TODO: compute rank IC on short horizon\n
